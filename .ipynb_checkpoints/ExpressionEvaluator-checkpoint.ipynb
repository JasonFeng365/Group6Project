# %% [markdown]
# # 1.Use MNIST dataset to train our model using handwritten recognition.

# %% [markdown]
# Make sure to install cv2 and tensorflow libraries before importing!!!

# %%
#Import all the libraries
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
# import our dataset using tensorflow
mnist = tf.keras.datasets.mnist

# %% [markdown]
# ### Preprocessing

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
x_train = tf.keras.utils.normalize(x_train, axis=1)
x_test = tf.keras.utils.normalize(x_test, axis=1)

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Flatten(input_shape=(28, 28)))
# Creating hidden layers of 128 neurons 
model.add(tf.keras.layers.Dense(128, activation='relu'))
model.add(tf.keras.layers.Dense(128, activation='relu'))

# Output layer with 10 neurons
model.add(tf.keras.layers.Dense(10, activation='softmax'))

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ### Training the model

# %%
model.fit(x_train, y_train, epochs=6)
# Out:
# Epoch 1/6
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0231 - accuracy: 0.9919
# Epoch 2/6
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0176 - accuracy: 0.9942
# Epoch 3/6
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0167 - accuracy: 0.9943
# Epoch 4/6
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0136 - accuracy: 0.9955
# Epoch 5/6
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0133 - accuracy: 0.9952
# Epoch 6/6
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.0110 - accuracy: 0.9958

# %%
model.save('handwritten.model')
# Out:
# INFO:tensorflow:Assets written to: handwritten.model\assets
# INFO:tensorflow:Assets written to: handwritten.model\assets

# %%
model = tf.keras.models.load_model('handwritten.model')

# %%
loss, accuracy = model.evaluate(x_test, y_test)
# Out:
# 313/313 [==============================] - 0s 912us/step - loss: 0.1202 - accuracy: 0.9742

# %%
print(loss)
print(accuracy)
# Out:
# 0.12022627890110016
# 0.9742000102996826

# %% [markdown]
# ## Testing it with my own handwritten numbers

# %%
image_number = 1

# Enable interactive mode for matplotlib
plt.ion()

image_number = 0

while os.path.isfile(f"digits_samples/digit{image_number}.png"):
    try:
        # Debugging statement
        print(f"Processing: digits_samples/digit{image_number}.png")
        
        img = cv2.imread(f"digits_samples/digit{image_number}.png")[:,:,0]
        img = np.invert(np.array([img]))
        
        # Ensure the image is correctly read and processed
        if img is not None:
            prediction = model.predict(img)
            print(f"This digit is probably a {np.argmax(prediction)}")
            plt.imshow(img[0], cmap=plt.cm.binary)
            plt.show()
        else:
            print(f"Failed to load image digits/digit{image_number}.png")
            
    except Exception as e:
        print(f"Error: {e}")
    finally:
        image_number += 1

# Turn off interactive mode
plt.ioff()
# Out:
# Processing: digits_samples/digit0.png
# 1/1 [==============================] - 0s 45ms/step
# This digit is probably a 0
# Processing: digits_samples/digit1.png
# 1/1 [==============================] - 0s 16ms/step
# This digit is probably a 1
# Processing: digits_samples/digit2.png
# 1/1 [==============================] - 0s 15ms/step
# This digit is probably a 2
# Processing: digits_samples/digit3.png
# 1/1 [==============================] - 0s 15ms/step
# This digit is probably a 3
# Processing: digits_samples/digit4.png
# 1/1 [==============================] - 0s 16ms/step
# This digit is probably a 2
# Processing: digits_samples/digit5.png
# 1/1 [==============================] - 0s 16ms/step
# This digit is probably a 3
# Processing: digits_samples/digit6.png
# 1/1 [==============================] - 0s 19ms/step
# This digit is probably a 3
# Processing: digits_samples/digit7.png
# 1/1 [==============================] - 0s 14ms/step
# This digit is probably a 6
# Processing: digits_samples/digit8.png
# 1/1 [==============================] - 0s 16ms/step
# This digit is probably a 8
# Processing: digits_samples/digit9.png
# 1/1 [==============================] - 0s 18ms/step
# This digit is probably a 5
